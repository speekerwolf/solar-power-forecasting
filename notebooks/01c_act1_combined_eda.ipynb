# %% [markdown]
# # Act 1 — Sub‑act C: PVDAQ + NSRDB combined EDA
#
# Same EDA stages as PVDAQ/NSRDB:
# 1) Snapshot tables
# 2) Sanity plots
# 3) Data issues
# 4) Insights recap
#
# This notebook will validate the **join and alignment** (timezone, cadence, overlap) and explore PV vs weather relationships.
