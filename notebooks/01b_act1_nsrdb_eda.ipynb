# %% [markdown]
# # Act 1 — Sub‑act B: NSRDB-only EDA
#
# Same EDA stages as PVDAQ:
# 1) Snapshot tables
# 2) Sanity plots
# 3) Data issues
# 4) Insights recap
#
# This notebook will explore **NSRDB-only** once we fetch/canonicalize NSRDB for the PVDAQ site/time range.
