# %% [markdown]
# # Act 2 — Feature engineering and classical ML
#
# Planned content:
# - Join PVDAQ output with NSRDB features on aligned timestamps
# - Baseline (linear), Random Forest, XGBoost
# - Time-aware validation and metrics (MAE, RMSE, R²)
#
# Implement in `src/features/`, `src/models/`, and `src/eval/`.

# %%
# Placeholder cell — Act 2 implementation follows after NSRDB alignment.
print("Act 2: TBD")
